# %% [markdown]
# https://www.kaggle.com/datasets/cyberprince/phishing-and-benign-email-dataset-short-version

# %%
import pandas as pd

# %%
df = pd.read_csv("./analysis/data/Advert_Spam.csv")
df.shape
# Out:
# (4592, 1)
